# %%
import pandas as pd

# %%
df_1 = pd.read_csv("/content/VGfsM1.csv")
df_2 = pd.read_csv("/content/m2mK1m.csv")

# %%
df_1.count()
# Out:
# paper         15
# title         15
# conference    15
# year          15
# dtype: int64

# %%
df_2.count()
# Out:
# paper         162
# title         162
# conference    162
# year          162
# dtype: int64

# %%
df = pd.concat([df_1, df_2], ignore_index=True)

# %%
df.columns
# Out:
# Index(['paper', 'title', 'conference', 'year'], dtype='object')

# %%
df.count()
# Out:
# paper         177
# title         177
# conference    177
# year          177
# dtype: int64

# %%
df[df.duplicated(keep=False)]
# Out:
#                                            paper  \
# 0        https://dblp.org/rec/conf/aaai/Werner24
# 3       https://dblp.org/rec/conf/acl/NandiKSM23
# 4       https://dblp.org/rec/conf/emnlp/SinghG23
# 5      https://dblp.org/rec/conf/nips/ChenCFHS23
# 11   https://dblp.org/rec/conf/aaai/BosselutBC21
# 24       https://dblp.org/rec/conf/aaai/Werner24
# 56      https://dblp.org/rec/conf/emnlp/SinghG23
# 85     https://dblp.org/rec/conf/nips/ChenCFHS23
# 92      https://dblp.org/rec/conf/acl/NandiKSM23
# 127  https://dblp.org/rec/conf/aaai/BosselutBC21
#
#                                                  title conference  year
# 0    Neuro-Symbolic Integration for Reasoning and L...       AAAI  2024
# 3    Simple Augmentations of Logical Rules for Neur...    ACL (2)  2023
# 4    NeuSTIP: A Neuro-Symbolic Model for Link and T...      EMNLP  2023
# 5    Differentiable Neuro-Symbolic Reasoning on Lar...    NeurIPS  2023
# ...

# %%
df = pd.concat([df_1, df_2], ignore_index=True).drop_duplicates()

# %%
df.count()
# Out:
# paper         172
# title         172
# conference    172
# year          172
# dtype: int64

# %%
conference_counts = df['conference'].value_counts()

# %%
conference_counts
# Out:
# conference
# AAAI                                 50
# IJCAI                                31
# NeurIPS                              28
# ICLR                                 17
# ICML                                 17
# EMNLP                                 9
# CVPR                                  7
# ACL (1)                               5
# ACL (2)                               2
# ICCV                                  2
# J. Mach. Learn. Res.                  2
# NAACL-HLT                             1
# Trans. Assoc. Comput. Linguistics     1
# Name: count, dtype: int64

# %%
df.to_csv("CompleteList.csv")

# %%
df_without_grey = pd.read_csv("/content/RemovedGrey.csv")

# %%
df_without_grey['conference'].value_counts()
# Out:
# conference
# AAAI                                 20
# NeurIPS                              17
# ICML                                 14
# IJCAI                                11
# ICLR                                 10
# EMNLP                                 6
# CVPR                                  4
# ACL (1)                               3
# ACL (2)                               2
# J. Mach. Learn. Res.                  2
# NAACL-HLT                             1
# Trans. Assoc. Comput. Linguistics     1
# Name: count, dtype: int64
